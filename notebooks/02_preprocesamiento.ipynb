# %% [markdown]
# # 02 — Preprocesamiento y Feature Engineering

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))

from discurso_odio.data.loader import load_dataset, prepare_dataset
from discurso_odio.features.preprocessing import preprocess_dataframe
from discurso_odio.features.text_features import extract_text_features

df = preprocess_dataframe(prepare_dataset(load_dataset('entrenamiento')))
features = extract_text_features(df)
print(df[['Texto_Original', 'texto_limpio', 'label']].head())
print(features.describe())
