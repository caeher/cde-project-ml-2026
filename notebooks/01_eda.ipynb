# %% [markdown]
# # 01 — Análisis Exploratorio de Datos (EDA)
#
# Corpus de discurso de odio en redes sociales salvadoreñas.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))

from discurso_odio.data.loader import load_dataset, prepare_dataset, label_distribution
from discurso_odio.eda.analysis import run_full_eda

df = load_dataset('unificado')
prepared = prepare_dataset(df)
print(f'Registros: {len(prepared)}')
print(label_distribution(df))

# %%
figures = run_full_eda(prepared)
for f in figures:
    print(f)
